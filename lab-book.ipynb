# %% [markdown]
# # Lab book:

# %%
# %matplotlib inline
import pandas as pd
import analysis
pd.options.display.float_format = "{:.1f}".format

# %% [markdown]
# # 1. Estudantes
#
# ## 1.1 Leitura dos dados

# %%
data = analysis.read_data_students()
data.head()
# Out:
#      idade sexo instituicao  periodo conhece como_conheceu usa  \
# 0  21 a 23    F     publica        5       S     faculdade   N
# 1  24 a 26    F     publica        5       S     faculdade   S
# 2  21 a 23    F     privada        5       S     faculdade   N
# 3  24 a 26    F     publica        5       S     faculdade   N
# 4  21 a 23    F     publica        5       S     faculdade   N
#
#                                       finalidade_uso  \
# 0                                                Não
# 1  Para avaliar e elaborar o plano de tratamento ...
# 2                                            Não uso
# 3                                            Não uso
# 4                                            NÃO USO
#
#                            motivo_nao_usa treinamento  \
# 0   Tenho dificuldades para aplicar a CIF           S
# 1                            Eu uso a CIF           S
# 2         Não conhecia essa classificação           S
# ...

# %% [markdown]
# ## 1.2 Caracterização da amostra
#
# ### 1.2.1 Dados gerais

# %%
analysis.table_sample_students(data)
# Out:
#   variavel  valores   n  percentual
# 0    idade  18 a 20   7        14.0
# 1    idade  21 a 23  35        70.0
# 2    idade  24 a 26   7        14.0
# 3    idade  27 a 29   1         2.0
# 0     sexo        F  43        86.0
# 1     sexo        M   7        14.0
# 0  periodo        3   4         8.0
# 1  periodo        4  13        26.0
# 2  periodo        5  33        66.0

# %% [markdown]
# ### 1.2.1 Variáveis relacionadas à CIF

# %%
analysis.table_sample_cif_students(data)
# Out:
#                variavel                                 valores   n  \
# 0               conhece                                       N   3
# 1               conhece                                       S  47
# 0        conhece_cif_cj                                       N  29
# 1        conhece_cif_cj                                       S  21
# 0     conhece_core_sets                                       N  45
# 1     conhece_core_sets                                       S   5
# 0                   usa                                       N  44
# 1                   usa                                       S   6
# 0        motivo_nao_usa                            Eu uso a CIF   7
# 1        motivo_nao_usa         Não conhecia essa classificação   5
# 2        motivo_nao_usa   Tenho dificuldades para aplicar a CIF  26
# 3        motivo_nao_usa  Tenho dificuldades para entender a CIF  12
# 0           treinamento                                       N  28
# ...

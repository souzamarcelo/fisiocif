# %% [markdown]
# # Lab book:

# %%
# %matplotlib inline
import pandas as pd
import analysis
pd.options.display.float_format = "{:.1f}".format

# %% [markdown]
# ## 1. Leitura dos dados

# %%
data = analysis.read_data()
print(len(data), 'estudantes responderam o questionário.')
data.head()
# Out:
# 50 estudantes responderam o questionário.
#      idade sexo  instituicao  periodo conhece como_conheceu usa  \
# 0  21 a 23    F    UNICENTRO        5       S     faculdade   N
# 1  24 a 26    F    UNICENTRO        5       S     faculdade   S
# 2  21 a 23    F  UNIGUAIRACÁ        5       S     faculdade   N
# 3  24 a 26    F    UNICENTRO        5       S     faculdade   N
# 4  21 a 23    F    UNICENTRO        5       S     faculdade   N
#
#                                       finalidade_uso  \
# 0                                                Não
# 1  Para avaliar e elaborar o plano de tratamento ...
# 2                                            Não uso
# 3                                            Não uso
# 4                                            NÃO USO
#
#                            motivo_nao_usa treinamento  \
# 0   Tenho dificuldades para aplicar a CIF           S
# 1                            Eu uso a CIF           S
# ...

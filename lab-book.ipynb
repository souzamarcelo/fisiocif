# %% [markdown]
# # Lab book:

# %%
# %matplotlib inline
import pandas as pd
import analysis
pd.options.display.float_format = "{:.1f}".format

# %% [markdown]
# # 1. Estudantes
#
# ## 1.1 Leitura dos dados

# %%
data = analysis.read_data_students()
data.head()
# Out:
#      idade sexo instituicao  periodo conhece como_conheceu usa  \
# 0  21 a 23    F     publica        5       S     faculdade   N
# 1  24 a 26    F     publica        5       S     faculdade   S
# 2  21 a 23    F     privada        5       S     faculdade   N
# 3  24 a 26    F     publica        5       S     faculdade   N
# 4  21 a 23    F     publica        5       S     faculdade   N
#
#                                       finalidade_uso  \
# 0                                                Não
# 1  Para avaliar e elaborar o plano de tratamento ...
# 2                                            Não uso
# 3                                            Não uso
# 4                                            NÃO USO
#
#                            motivo_nao_usa treinamento  \
# 0   Tenho dificuldades para aplicar a CIF           S
# 1                            Eu uso a CIF           S
# 2         Não conhecia essa classificação           S
# ...

# %% [markdown]
# ## 1.2 Caracterização da amostra
#
# ### 1.2.1 Dados gerais

# %%
analysis.table_sample_students(data)
# Out:
#   variavel  valores   n  percentual
# 0    idade  18 a 20   7        14.0
# 1    idade  21 a 23  35        70.0
# 2    idade  24 a 26   7        14.0
# 3    idade  27 a 29   1         2.0
# 0     sexo        F  43        86.0
# 1     sexo        M   7        14.0
# 0  periodo        3   4         8.0
# 1  periodo        4  13        26.0
# 2  periodo        5  33        66.0

# %% [markdown]
# ### 1.2.2 Variáveis relacionadas à CIF

# %%
analysis.table_sample_cif_students(data)
# Out:
#                variavel                                 valores   n  \
# 0               conhece                                       N   3
# 1               conhece                                       S  47
# 0        conhece_cif_cj                                       N  29
# 1        conhece_cif_cj                                       S  21
# 0     conhece_core_sets                                       N  45
# 1     conhece_core_sets                                       S   5
# 0                   usa                                       N  44
# 1                   usa                                       S   6
# 0        motivo_nao_usa                            Eu uso a CIF   7
# 1        motivo_nao_usa         Não conhecia essa classificação   5
# 2        motivo_nao_usa   Tenho dificuldades para aplicar a CIF  26
# 3        motivo_nao_usa  Tenho dificuldades para entender a CIF  12
# 0           treinamento                                       N  28
# ...

# %% [markdown]
# ## 1.3 Análise visual
#
# ### 1.3.1 Características segundo instituição (pública ou privada)

# %%
analysis.plot_institution(data)
# Out:
# <module 'matplotlib.pyplot' from '/home/marcelo/.venvs/myenv/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ### 1.3.2 Características segundo fase do curso

# %%
analysis.plot_year(data)
# Out:
# <module 'matplotlib.pyplot' from '/home/marcelo/.venvs/myenv/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ### 1.3.3 Nível de conhecimento

# %%
analysis.plot_knowledge(data)
# Out:
# <module 'matplotlib.pyplot' from '/home/marcelo/.venvs/myenv/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ### 1.3.4 Motivos do não uso

# %%
analysis.plot_reason(data)
# Out:
# <module 'matplotlib.pyplot' from '/home/marcelo/.venvs/myenv/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# ### 1.3.5 Adoção na pediatria

# %% [markdown]
# # 2. Profissionais
#
# ## 2.1 Leitura dos dados

# %%
data = analysis.read_data_professionals()
data.head()
# Out:
#      idade sexo tempo_formado instituicao                 especialidade  \
# 0     > 40    F       11 a 15     privada  Fisioterapia Neurofuncional
# 1  31 a 35    F       11 a 15     publica      Ortopedia/saúde coletiva
# 2     > 40    F   Mais que 15     publica            Terapia intensiva
# 3     > 40    F   Mais que 15     privada   Fisioterapia neurofuncional
# 4     > 40    F   Mais que 15     publica           Cardiorrespiratória
#
#         instrucao             local_trabalho         nivel_trabalho conhece  \
# 0       Doutorado  Rede pública e particular             Domiciliar       S
# 1        Mestrado  Rede pública e particular  Ambulatorial/ Clínica       S
# 2  Especialização  Rede pública e particular             Hospitalar       S
# 3       Doutorado               Rede pública  Ambulatorial/ Clínica       S
# 4       Doutorado  Rede pública e particular                    NaN       S
#
#                            como_conheceu  ...  \
# ...

# %% [markdown]
# ## 2.2 Caracterização da amostra
#
# ### 2.2.1 Dados gerais

# %%
analysis.table_sample_professionals(data)
# Out:
#          variavel                                 valores  n  percentual
# 0           idade                                 26 a 30  1        12.5
# 1           idade                                 31 a 35  3        37.5
# 2           idade                                    > 40  4        50.0
# 0            sexo                                       F  8       100.0
# 0   tempo_formado                                 11 a 15  3        37.5
# 1   tempo_formado                                  6 a 10  2        25.0
# 2   tempo_formado                             Mais que 15  3        37.5
# 0     instituicao                                 privada  3        37.5
# 1     instituicao                                 publica  5        62.5
# 0   especialidade                     Cardiorrespiratória  1        12.5
# 1   especialidade            Fisioterapia Neurofuncional   1        12.5
# 2   especialidade             Fisioterapia neurofuncional  1        12.5
# ...

# %% [markdown]
# ### 2.2.2 Variáveis relacionadas à CIF

# %%
analysis.table_sample_cif_professionals(data)
# Out:
#                variavel                                valores  n  percentual
# 0               conhece                                      S  8       100.0
# 0        conhece_cif_cj                                      N  3        37.5
# 1        conhece_cif_cj                                      S  5        62.5
# 0     conhece_core_sets                                      N  3        37.5
# 1     conhece_core_sets                                      S  5        62.5
# 0                   usa                                      N  3        37.5
# 1                   usa                                      S  5        62.5
# 0        motivo_nao_usa                           Eu uso a CIF  5        62.5
# 1        motivo_nao_usa  Tenho dificuldades para aplicar a CIF  3        37.5
# 0           treinamento                                      N  2        25.0
# 1           treinamento                                      S  6        75.0
# ...

# %% [markdown]
# ## 2.3 Análise visual
#
# ### 2.3.1 Características segundo a instituição

# %%
#Relação de  avaliação do conhecimento com a IES que formou

# %% [markdown]
# ### 2.3.2 Características segundo o grau de instrução

# %%
#o grau de instrição vs uso e avaliação do conhecimento

# %% [markdown]
# ### 2.3.3 Adoção na pediatria

# %%
#conhecer os core sets vs usar e estar preparado
